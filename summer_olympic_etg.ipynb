# %% [markdown]
# ***Summer Olympics Data Analysis Assignment***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Reading the Data**

# %%
df = pd.read_csv("summer.csv")
df
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# ...

# %% [markdown]
# **1. In how many cities Summer Olympics is held so far?**

# %%
print("Name of the cities in which Summer Olympics were held  so far are:" ,df['City'].unique())
# Out:
# Name of the cities in which Summer Olympics were held  so far are: ['Athens' 'Paris' 'St Louis' 'London' 'Stockholm' 'Antwerp' 'Amsterdam'
#  'Los Angeles' 'Berlin' 'Helsinki' 'Melbourne / Stockholm' 'Rome' 'Tokyo'
#  'Mexico' 'Munich' 'Montreal' 'Moscow' 'Seoul' 'Barcelona' 'Atlanta'
#  'Sydney' 'Beijing']

# %%
print("Number of cities in which Summer Olympics were held  so far are:" ,len(df['City'].unique()))
# Out:
# Number of cities in which Summer Olympics were held  so far are: 22

# %% [markdown]
# **2. Which sport is having most number of Gold Medals so far?**

# %%
data = df.values
lst = []
for Sport in df['Sport'].unique():
  var = 0
  for i in range(len(data)):
      if (data[i][2] == Sport and data[i][8] == 'Gold'):
        var += 1
  lst.append([Sport,var])
lst
# Out:
# [['Aquatics', 1421],
#  ['Athletics', 1215],
#  ['Cycling', 371],
#  ['Fencing', 552],
#  ['Gymnastics', 820],
#  ['Shooting', 384],
#  ['Tennis', 92],
#  ['Weightlifting', 200],
#  ['Wrestling', 391],
#  ['Archery', 126],
#  ['Basque Pelota', 2],
#  ['Cricket', 12],
#  ['Croquet', 4],
#  ['Equestrian', 320],
#  ['Football', 503],
#  ['Golf', 13],
#  ['Polo', 22],
#  ['Rowing', 890],
#  ['Rugby', 78],
#  ['Sailing', 412],
#  ['Tug of War', 36],
#  ['Boxing', 239],
#  ['Lacrosse', 28],
#  ['Roque', 1],
#  ['Hockey', 486],
#  ['Jeu de paume', 1],
#  ['Rackets', 3],
#  ['Skating', 9],
#  ['Water Motorsports', 5],
#  ['Modern Pentathlon', 60],
#  ['Ice Hockey', 8],
#  ['Basketball', 342],
#  ['Canoe / Kayak', 334],
#  ['Handball', 321],
#  ['Judo', 123],
#  ['Volleyball', 332],
#  ['Table Tennis', 46],
#  ['Badminton', 46],
#  ['Baseball', 111],
#  ['Softball', 60],
#  ['Taekwondo', 32],
#  ['Triathlon', 8],
#  ['Canoe', 27]]

# %%
no = []
for i in range(0,len(lst)):
  no.append(lst[i][1])
for i in range(0,len(lst)):
  if (max(no)==lst[i][1]):
    spt = lst[i][0]
    break
  break
print("Sport which is having most number of Gold Medals so far:",spt)
print("Number of Gold Medals",spt,"sport is having are:",max(no))
# Out:
# Sport which is having most number of Gold Medals so far: Aquatics
# Number of Gold Medals Aquatics sport is having are: 1421

# %% [markdown]
# **Graphical Analysis of Sports having Gold Medal**

# %%
pd.DataFrame(lst,columns = ["Sport","Number of Gold Medals"]).sort_values(by='Sport', ascending= True).plot(x = 'Sport', y = 'Number of Gold Medals', kind = 'bar', figsize = (20,5))

# %% [markdown]
# **Graphical Analysis of Top 5 Sports having Gold Medal**

# %%
gd = df[df['Medal'] == 'Gold']
gd = gd.groupby('Sport').count()['Medal'].sort_values(ascending = False).head()
print(gd)
gd.plot.bar(figsize =(10,5))
# Out:
# Sport
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Medal, dtype: int64

# %% [markdown]
# **3. Which sport is having most number of medals so far?**

# %%
data = df.values
md = []
for Sport in df['Sport'].unique():
  ct = 0
  for i in range(len(data)):
      if (data[i][2] == Sport and data[i][8] != None):
        ct += 1
  md.append([Sport,ct])
md
# Out:
# [['Aquatics', 4170],
#  ['Athletics', 3638],
#  ['Cycling', 1105],
#  ['Fencing', 1613],
#  ['Gymnastics', 2307],
#  ['Shooting', 1150],
#  ['Tennis', 296],
#  ['Weightlifting', 593],
#  ['Wrestling', 1212],
#  ['Archery', 329],
#  ['Basque Pelota', 4],
#  ['Cricket', 24],
#  ['Croquet', 8],
#  ['Equestrian', 939],
#  ['Football', 1497],
#  ['Golf', 30],
#  ['Polo', 66],
#  ['Rowing', 2667],
#  ['Rugby', 192],
#  ['Sailing', 1109],
#  ['Tug of War', 94],
#  ['Boxing', 894],
#  ['Lacrosse', 59],
#  ['Roque', 3],
#  ['Hockey', 1422],
#  ['Jeu de paume', 3],
#  ['Rackets', 10],
#  ['Skating', 27],
#  ['Water Motorsports', 5],
#  ['Modern Pentathlon', 180],
#  ['Ice Hockey', 27],
#  ['Basketball', 1012],
#  ['Canoe / Kayak', 1002],
#  ['Handball', 973],
#  ['Judo', 491],
#  ['Volleyball', 994],
#  ['Table Tennis', 144],
#  ['Badminton', 144],
#  ['Baseball', 335],
#  ['Softball', 180],
#  ['Taekwondo', 112],
#  ['Triathlon', 24],
#  ['Canoe', 81]]

# %%
nu = []
for i in range(0,len(md)):
  nu.append(md[i][1])
for i in range(0,len(md)):
  if (max(nu)==md[i][1]):
    spot = md[i][0]
    break
  break
print("Sport which is having most number of Medals so far:",spot)
print("Number of Medals",spot,"sport is having are:",max(nu))
# Out:
# Sport which is having most number of Medals so far: Aquatics
# Number of Medals Aquatics sport is having are: 4170

# %% [markdown]
# **Graphical Analysis of Sports having most number of Medals**

# %%
pd.DataFrame(md,columns = ["Sport","Number of Medals"]).sort_values(by='Sport', ascending= True).plot(x = 'Sport', y = 'Number of Medals', kind = 'bar', figsize = (20,5))

# %% [markdown]
# **Graphical Analysis of Top 5 Sports having most number of Medals**

# %%
m =df.groupby('Sport').count()['Medal'].sort_values(ascending = False).head()
print(m)
m.plot.bar(figsize = (10, 5))
# Out:
# Sport
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Medal, dtype: int64

# %% [markdown]
# **4. Which player has won most number of medals?**

# %%
data = df.values
pl = []
for Athlete in df['Athlete'].unique():
  cn = 0
  for i in range(len(data)):
      if (data[i][4] == Athlete and data[i][8] != None):
        cn += 1
  pl.append([Athlete,cn])
pl
# Out:
# [['HAJOS, Alfred', 2],
#  ['HERSCHMANN, Otto', 2],
#  ['DRIVAS, Dimitrios', 1],
#  ['MALOKINIS, Ioannis', 1],
#  ['CHASAPIS, Spiridon', 1],
#  ['CHOROPHAS, Efstathios', 2],
#  ['ANDREOU, Joannis', 1],
#  ['NEUMANN, Paul', 1],
#  ['PEPANOS, Antonios', 1],
#  ['LANE, Francis', 1],
#  ['SZOKOLYI, Alajos', 1],
#  ['BURKE, Thomas', 2],
#  ['HOFMANN, Fritz', 4],
#  ['CURTIS, Thomas', 1],
#  ['GOULDING, Grantley', 1],
#  ['LERMUSIAUX, Albin', 1],
#  ['FLACK, Edwin', 3],
#  ['BLAKE, Arthur', 1],
#  ['GMELIN, Charles', 1],
#  ['JAMISON, Herbert', 1],
#  ['GOLEMIS, Dimitrios', 1],
#  ['DANI, Nandor', 1],
#  ['VERSIS, Sotirios', 2],
#  ['GARRETT, Robert', 6],
#  ['PARASKEVOPOULOS, Panagiotis', 1],
#  ['CLARK, Ellery', 2],
#  ['CONNOLLY, James', 5],
#  ['KELLNER, Gyula', 1],
#  ['LOUIS, Spyridon', 1],
#  ['VASILAKOS, Kharilaos', 1],
#  ['DAMASKOS, Evangelos', 1],
#  ['THEODOROPOULOS, Ioannis', 1],
#  ['HOYT, William Welles', 1],
#  ['TYLER, Albert', 1],
#  ['PAPASIDERIS, Georgios', 1],
# ...

# %%
nm = []
for i in range(0,len(pl)):
  nm.append(pl[i][1])

# %%
for i in range(len(pl)):
  if (max(nm) == pl[i][1]):
    print("Player who has won most number of medals:",pl[i][0])
    print("Number of Medals",pl[i][0],"has won:",max(nm))
# Out:
# Player who has won most number of medals: PHELPS, Michael
# Number of Medals PHELPS, Michael has won: 22

# %% [markdown]
# **Graphical Analysis of Top 5 Players and number of Medals they won**

# %%
pler = df.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head()
print(pler)
pler.plot.bar(figsize= (10,5))
# Out:
# Athlete
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# SHAKHLIN, Boris         13
# Name: Medal, dtype: int64

# %% [markdown]
# **5. Which player has won most number Gold Medals of medals?**

# %%
data = df.values
ms = []
for Athlete in df['Athlete'].unique():
  cp = 0
  for i in range(len(data)):
      if (data[i][4] == Athlete and data[i][8] == 'Gold'):
        cp += 1
  ms.append([Athlete,cp])
ms
# Out:
# [['HAJOS, Alfred', 2],
#  ['HERSCHMANN, Otto', 0],
#  ['DRIVAS, Dimitrios', 0],
#  ['MALOKINIS, Ioannis', 1],
#  ['CHASAPIS, Spiridon', 0],
#  ['CHOROPHAS, Efstathios', 0],
#  ['ANDREOU, Joannis', 0],
#  ['NEUMANN, Paul', 1],
#  ['PEPANOS, Antonios', 0],
#  ['LANE, Francis', 0],
#  ['SZOKOLYI, Alajos', 0],
#  ['BURKE, Thomas', 2],
#  ['HOFMANN, Fritz', 2],
#  ['CURTIS, Thomas', 1],
#  ['GOULDING, Grantley', 0],
#  ['LERMUSIAUX, Albin', 0],
#  ['FLACK, Edwin', 2],
#  ['BLAKE, Arthur', 0],
#  ['GMELIN, Charles', 0],
#  ['JAMISON, Herbert', 0],
#  ['GOLEMIS, Dimitrios', 0],
#  ['DANI, Nandor', 0],
#  ['VERSIS, Sotirios', 0],
#  ['GARRETT, Robert', 2],
#  ['PARASKEVOPOULOS, Panagiotis', 0],
#  ['CLARK, Ellery', 2],
#  ['CONNOLLY, James', 1],
#  ['KELLNER, Gyula', 0],
#  ['LOUIS, Spyridon', 1],
#  ['VASILAKOS, Kharilaos', 0],
#  ['DAMASKOS, Evangelos', 0],
#  ['THEODOROPOULOS, Ioannis', 0],
#  ['HOYT, William Welles', 1],
#  ['TYLER, Albert', 0],
#  ['PAPASIDERIS, Georgios', 0],
# ...

# %%
mp = []
for i in range(0,len(ms)):
  mp.append(ms[i][1])

# %%
for i in range(len(ms)):
  if (max(mp) == ms[i][1]):
    print("Player who has won most number of Gold medals:",ms[i][0])
    print("Number of Gold Medals",ms[i][0],"has won:",max(mp))
# Out:
# Player who has won most number of Gold medals: PHELPS, Michael
# Number of Gold Medals PHELPS, Michael has won: 18

# %% [markdown]
# **Graphical Analysis of Top 5 Player who won Gold Medal and number of Gold Medals Player Won**

# %%
pler_gd=df[df['Medal']=='Gold']
pler_gd=pler_gd.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head()
print(pler_gd)
pler_gd.plot.bar(figsize=(10,5))
# Out:
# Athlete
# PHELPS, Michael     18
# NURMI, Paavo         9
# SPITZ, Mark          9
# LEWIS, Carl          9
# LATYNINA, Larisa     9
# Name: Medal, dtype: int64

# %% [markdown]
# **6. In which year India won first Gold Medal in Summer Olympics?**

# %%
player=df[df['Medal']=='Gold']
yr=player.sort_values(['Year'],ascending=True)

gld=yr[yr['Country']=='IND'].iloc[0]

print("The year in which India won it's First Gold Medal in Summer Olympics is ",gld['Year'] ,"\n")
print(gld)
# Out:
# The year in which India won it's First Gold Medal in Summer Olympics is  1928
#
# Year                 1928
# City            Amsterdam
# Sport              Hockey
# Discipline         Hockey
# Athlete       CHAND, Dyan
# Country               IND
# Gender                Men
# Event              Hockey
# Medal                Gold
# Name: 5513, dtype: object

# %% [markdown]
# **7. Which event is most popular in terms on number of players?**

# %%
poplr = df.groupby('Event').count()['Athlete'].sort_values(ascending=False).head()
print(poplr)
poplr.plot.bar(figsize = (10,5))
# Out:
# Event
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Athlete, dtype: int64

# %% [markdown]
# **Football** is the most popular sport with **1497** number of players who participated in it

# %% [markdown]
# **8. Which sport is having most female Gold Medalists?**

# %%
plrgd=df[df['Medal']=='Gold']
plrfemgd=plrgd[df['Gender']=='Women']
plrfemgd=plrfemgd.groupby('Sport').count()['Medal'].sort_values(ascending=False).head()
print(plrfemgd)
plrfemgd.plot.bar(figsize=(10,5))
# Out:
# Sport
# Aquatics      589
# Athletics     389
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Medal, dtype: int64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# **Aquatics** sports has the most number of Female Gold Medalists with **589** Gold Medals
